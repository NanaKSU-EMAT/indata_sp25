# %% [markdown]
# One visual i would like to learn would be "Visualizing Trends" and the graph most commonly used for this would be a line graph
# with my career goal being a UX/UI designer I would be particularly interested in visualizing the trends in user engagement across different versions of a webpage or mobile app. For example: How many users click on a specific button (e.g., "Sign Up" or "Learn More") over a week or month, ages of individuals and how long they interact with the interface and other interaction rates(e.g.,scroll depth, data usage etc.)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cces= pd.read_csv("cces_example_data.csv")

# %%
cces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig1, axs1= plt.subplots(1, 2) 
axs1[0].set_title("Age Histogram")
axs1[1].set_title("Political Identity")
plt.show()

# %%
# Summarize the frequencies of the 'Evaluation' variable
evaluation_counts = cces.groupby("Evaluation").count()
evaluation_counts
# Out:
#             pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  \
# Evaluation
# 0                    365          365  365   365       365  365         365
# 1                     48           48   48    48        48   48          48
# 2                    202          202  202   202       202  202         202
# 3                     44           44   44    44        44   44          44
#
#             pid3  ideo5  QueerPhobia  ImmiPhobia  InterGBiasParty  \
# Evaluation
# 0            365    365          365         365              365
# 1             48     48           48          48               48
# 2            202    202          202         202              202
# 3             44     44           44          44               44
#
#             InterGBiasCand  InterGBiasSup  LibMediaUse  ConMediaUse  \
# Evaluation
# 0                      365            365          365          365
# 1                       48             48           48           48
# ...

# %%
evaluation_count= cces['Evaluation'].value_counts()

# %%
evaluation_count
# Out:
# Evaluation
# 0    365
# 2    202
# 1     48
# 3     44
# Name: count, dtype: int64

# %%
fig2, ax2 = plt.subplots()
ax2.bar(x=evaluation_count.index, height= evaluation_count.values)
plt.show()

# %%
fig3,ax3=plt.subplots()
ax3.scatter(cces["ConMediaUse"],cces["ImmiPhobia"])
ax3.scatter(cces["ImmiPhobia"], cces["ConMediaUse"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# To improve the scatter plot, we could apply several techniques:
# 1.Modify the marker size and style to ensure that points are more distinguishable. You can also scale the marker size based on another variable.
# 2.Creating subplots to compare scatterplots for different categories (e.g., sex, nonwhite) to make it easier to identify differences across groups.
# 3.By adding transparency you can reduce the intensity of overlapping points, making it easier to identify patterns. This allows for the identification of areas with higher densities of points.
#
# REFENCES
# Section:Part II: Principles of figure design, Chapter 20.2
# Section:Part II: Principles of figure design,Chapter 18.1
# Section:Part II: Principles of figure design,Chapter 23.1
